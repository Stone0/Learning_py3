# %%
import codecs
filename = r"《人为什么活着》TXT(全).txt"
with codecs.open(filename) as f:
    mytext = f.read()
mytext[:500]
# Out:
# '人 为 什 么 活 着\n稻盛和夫的哲学\n【日】稻盛和夫  著\n吕美女  译\n编辑手记——稻盛和夫的过冬术\t2\n编者按\t3\n稻盛和夫答王石、《IT经理世界》问\t3\n推荐一：从一种个人价值观到一种企业家精神\t5\n推荐二：人生的格局\t7\n推荐三：稻盛和夫的人生观\t9\n稻盛和夫的经营哲学\t11\n第一部分  与宇宙意志相和谐\t14\n第一章  人类存在于生存的价值\t14\n第二章  宇宙\t15\n第三章  心智\t17\n第四章  造物主\t20\n第五章  欲望\t22\n第六章  意识与灵魂\t23\n第七章  科学\t26\n第二部分  秉持利他之心而活\t27\n第八章  人类的本性\t27\n第九章   自由\t29\n第十章  青少年犯罪\t31\n第十一章  人生的目的\t32\n第十二章  命运与因果报应\t34\n第十三章  人生的考验\t37\n第十四章   苦恤与槽恨\t39\n第三部分   让心智提升到更高的境界\t41\n第十五章  逆境\t41\n第十六章  情与理\t43\n第十七章  勤劳\t45\n第十八章  宗教与死亡\t47\n第十九章  共生与竞争\t50\n第十二章  知足之道\t52\n第二十一章  我走过的路\t53\n附  录\t57\n“'

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

alice_coloring = np.array(Image.open("wsc.jpg"))

stopwords = set(STOPWORDS)
stopwords.add("said")

wordcloud = WordCloud(font_path="simsun.ttf", background_color="white", max_words=500, mask=alice_coloring,
               stopwords=stopwords, random_state=42, scale=3).generate(mytext)

image_colors = ImageColorGenerator(alice_coloring)


# 默认的像素：[6.0,4.0]，分辨率为100，图片尺寸为 600&400
# 指定dpi=200，图片尺寸为 1200*800
# 指定dpi=300，图片尺寸为 1800*1200
# 设置figsize可以在不改变分辨率情况下改变比例
plt.rcParams['figure.figsize'] = (6, 4) #设置figure_size尺寸
plt.rcParams['figure.dpi'] = 300 #分辨率

plt.imshow(WordCloud(font_path="simsun.ttf", scale=3).generate(mytext), interpolation='bilinear')
plt.axis("off")
plt.figure()

plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
plt.figure()

# plt.imshow(alice_coloring, cmap=plt.cm.gray, interpolation="bilinear")
# plt.axis("off")
# plt.figure()

# plt.show()

# %%
alice_coloring = np.array(Image.open("wsc.jpg"))
plt.rcParams['figure.dpi'] = 200 #分辨率
plt.rcParams['figure.figsize'] = (8.0, 4.0) # 设置figure_size尺寸
plt.imshow(alice_coloring, cmap=plt.cm.gray, interpolation="bilinear")
plt.axis("off")
plt.figure()
plt.show()
